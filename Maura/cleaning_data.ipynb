# %% [markdown]
# # Cleaning the Data and exporting to national, state, and county csv files.

# %%
import pandas as pd

# %%
#making sure we don't lose the leading zeroes in the zip codes
zip_code_column = 'LocationID'

heart_disease_df = pd.read_csv("../Resources/Heart_Disease_Mortality2019-2021.csv", dtype={zip_code_column: str})

heart_disease_df.head()
# Out:
#    Year LocationAbbr           LocationDesc GeographicLevel DataSource  \
# 0  2020           AK        Kenai Peninsula          County       NVSS
# 1  2020           AL          Walker County          County       NVSS
# 2  2020           AL       St. Clair County          County       NVSS
# 3  2020           AR            Yell County          County       NVSS
# 4  2020           AS  American Samoa County          County       NVSS
#
#                      Class                    Topic  Data_Value  \
# 0  Cardiovascular Diseases  Heart Disease Mortality       165.1
# 1  Cardiovascular Diseases  Heart Disease Mortality       109.0
# 2  Cardiovascular Diseases  Heart Disease Mortality        90.0
# 3  Cardiovascular Diseases  Heart Disease Mortality         NaN
# 4  Cardiovascular Diseases  Heart Disease Mortality         NaN
#
#           Data_Value_Unit                                    Data_Value_Type  \
# 0  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 1  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 2  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 3  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
# 4  per 100,000 population  Age-adjusted, Spatially Smoothed, 3-year Avera...
#
#    ... Data_Value_Footnote StratificationCategory1 Stratification1  \
# 0  ...                 NaN                  Gender            Male
# 1  ...                 NaN                  Gender         Overall
# 2  ...                 NaN                  Gender         Overall
# 3  ...   Insufficient Data                  Gender          Female
# 4  ...   Insufficient Data                  Gender            Male
#
#   StratificationCategory2 Stratification2 TopicID LocationID      Y_lat  \
# 0          Race/Ethnicity        Hispanic      T2      02122  60.193263
# 1          Race/Ethnicity        Hispanic      T2      01127  33.810226
# 2          Race/Ethnicity           Asian      T2      01115  33.716065
# 3          Race/Ethnicity           Asian      T2      05149  35.005864
# 4          Race/Ethnicity           Black      T2      60000 -14.301754
#
#         X_lon                       Georeference
# 0 -150.280744  POINT (-150.2807443 60.193262972)
# 1  -87.297070  POINT (-87.29707047 33.810226394)
# 2  -86.314960  POINT (-86.31496031 33.716065391)
# 3  -93.401676   POINT (-93.40167591 35.00586398)
# 4 -170.719474  POINT (-170.7194738 -14.30175426)
#
# [5 rows x 21 columns]

# %%
heart_disease_df.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'GeographicLevel', 'DataSource',
#        'Class', 'Topic', 'Data_Value', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'TopicID', 'LocationID', 'Y_lat', 'X_lon',
#        'Georeference'],
#       dtype='object')

# %%
#clean the dataset and rename columns
heart_disease_df = heart_disease_df[['LocationAbbr', 'LocationDesc', 'GeographicLevel', 'Data_Value', 'Stratification1','Stratification2','LocationID', 'Y_lat', 'X_lon']]

heart_disease_df = heart_disease_df.rename(columns={
    "LocationAbbr": "State",
    "LocationDesc": "LocationDesc",
    "GeographicLevel": "GeographicLevel",
    "Data_Value": "Data Value (Per 100,000 Population)",
    "Stratification1": "Gender",
    "Stratification2": "Race/Ethnicity",
    "LocationID": "LocationID",
    "Y_lat": "Latitude",
    "X_lon": "Longitude"
})
heart_disease_df.head()
# Out:
#   State           LocationDesc GeographicLevel  \
# 0    AK        Kenai Peninsula          County
# 1    AL          Walker County          County
# 2    AL       St. Clair County          County
# 3    AR            Yell County          County
# 4    AS  American Samoa County          County
#
#    Data Value (Per 100,000 Population)   Gender Race/Ethnicity LocationID  \
# 0                                165.1     Male       Hispanic      02122
# 1                                109.0  Overall       Hispanic      01127
# 2                                 90.0  Overall          Asian      01115
# 3                                  NaN   Female          Asian      05149
# 4                                  NaN     Male          Black      60000
#
#     Latitude   Longitude
# 0  60.193263 -150.280744
# 1  33.810226  -87.297070
# 2  33.716065  -86.314960
# 3  35.005864  -93.401676
# 4 -14.301754 -170.719474

# %%
#state only csv
state_hd_df = heart_disease_df.loc[heart_disease_df["GeographicLevel"] == "State"]
state_hd_df.head()
# Out:
#    State    LocationDesc GeographicLevel  Data Value (Per 100,000 Population)  \
# 12    IN         Indiana           State                                118.5
# 19    NE        Nebraska           State                                120.1
# 22    NY        New York           State                                 83.4
# 54    GU            Guam           State                                  NaN
# 86    AS  American Samoa           State                                  NaN
#
#      Gender      Race/Ethnicity LocationID  Latitude  Longitude
# 12   Female               Asian         18   39.9128   -86.2757
# 19     Male               Asian         31   41.5228   -99.8085
# 22  Overall  More than one race         36   42.9465   -75.5120
# 54   Female               Black         66   13.4431   144.7770
# 86     Male             Overall         60  -14.2766  -170.3670

# %%
#county only csv
county_hd_df = heart_disease_df.loc[heart_disease_df["GeographicLevel"] == "County"]
county_hd_df.head()
# Out:
#   State           LocationDesc GeographicLevel  \
# 0    AK        Kenai Peninsula          County
# 1    AL          Walker County          County
# 2    AL       St. Clair County          County
# 3    AR            Yell County          County
# 4    AS  American Samoa County          County
#
#    Data Value (Per 100,000 Population)   Gender Race/Ethnicity LocationID  \
# 0                                165.1     Male       Hispanic      02122
# 1                                109.0  Overall       Hispanic      01127
# 2                                 90.0  Overall          Asian      01115
# 3                                  NaN   Female          Asian      05149
# 4                                  NaN     Male          Black      60000
#
#     Latitude   Longitude
# 0  60.193263 -150.280744
# 1  33.810226  -87.297070
# 2  33.716065  -86.314960
# 3  35.005864  -93.401676
# 4 -14.301754 -170.719474

# %%
#national csv
national_hd_df = heart_disease_df.loc[heart_disease_df["GeographicLevel"] == "Nation"]
national_hd_df.head()
# Out:
#       State   LocationDesc GeographicLevel  \
# 67197    US  United States          Nation
# 67973    US  United States          Nation
# 68318    US  United States          Nation
# 69192    US  United States          Nation
# 69416    US  United States          Nation
#
#        Data Value (Per 100,000 Population)   Gender  \
# 67197                                165.1  Overall
# 67973                                253.6   Female
# 68318                                292.3     Male
# 69192                                218.5   Female
# 69416                                417.5     Male
#
#                                   Race/Ethnicity LocationID  Latitude  \
# 67197                                      Asian          0       NaN
# 67973                                    Overall          0       NaN
# 68318                                   Hispanic          0       NaN
# 69192           American Indian or Alaska Native          0       NaN
# 69416  Native Hawaiian or Other Pacific Islander          0       NaN
#
#        Longitude
# 67197        NaN
# 67973        NaN
# 68318        NaN
# 69192        NaN
# 69416        NaN

# %%
heart_disease_df.to_csv("../Resources/clean_Heart_Disease.csv")
state_hd_df.to_csv("../Resources/state_Heart_Disease.csv")
county_hd_df.to_csv("../Resources/county_Heart_Disease.csv")
national_hd_df.to_csv("../Resources/national_Heart_Disease.csv")
