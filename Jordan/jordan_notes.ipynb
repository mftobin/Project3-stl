# %%
import pandas as pd 

data = pd.read_csv("../Resources/clean_Heart_Disease.csv")
data.head()
# Out:
#    Unnamed: 0 State           LocationDesc GeographicLevel  \
# 0           0    AK        Kenai Peninsula          County
# 1           1    AL          Walker County          County
# 2           2    AL       St. Clair County          County
# 3           3    AR            Yell County          County
# 4           4    AS  American Samoa County          County
#
#    Data Value (Per 100,000 Population)   Gender Race/Ethnicity  LocationID  \
# 0                                165.1     Male       Hispanic        2122
# 1                                109.0  Overall       Hispanic        1127
# 2                                 90.0  Overall          Asian        1115
# 3                                  NaN   Female          Asian        5149
# 4                                  NaN     Male          Black       60000
#
#     Latitude   Longitude
# 0  60.193263 -150.280744
# 1  33.810226  -87.297070
# 2  33.716065  -86.314960
# 3  35.005864  -93.401676
# 4 -14.301754 -170.719474

# %%
#Filter for necessary clomuns and export to JSON 
filtered_data = data[['State', 'Gender', 'Race/Ethnicity', 'Data Value (Per 100,000 Population)']].dropna()
filtered_data.to_json("heart_disease_data.json", orient="records")
